# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Data Reading

# %%
users_df = pd.read_csv("../datasets/users.csv")
items_df = pd.read_csv("../datasets/items.csv")

# %%
users_df.head()
# Out:
#    شناسه کاربر  سن جنسیت اولویت دسته‌بندی 1     اولویت دسته‌بندی 2  \
# 0            1  50    زن        خانه و دکور        پوشاک و اکسسوری
# 1            2  65    زن    پوشاک و اکسسوری        پوشاک و اکسسوری
# 2            3  44   مرد          الکترونیک  کتاب و محصولات آموزشی
# 3            4  12   مرد        خانه و دکور              الکترونیک
# 4            5  31    زن        خانه و دکور              الکترونیک
#
#    اولویت دسته‌بندی 3 ویژگی روان‌شناختی علاقه به متریال سبک کاری مورد علاقه  \
# 0           الکترونیک   احساسی و حمایتی             خاص                مدرن
# 1           الکترونیک          درون‌گرا           پارچه            منطقه‌ای
# 2  ورزش و تناسب اندام   احساسی و حمایتی           پارچه        فانتزی و خاص
# 3         خانه و دکور          برون‌گرا   شیشه و سرامیک         لوکس و رسمی
# 4           الکترونیک          برون‌گرا           پارچه            منطقه‌ای
#
#          مناسبت هدیه نوع ارتباط با فرد گیرنده هدیه
# 0              عروسی                       خانواده
# ...

# %%
items_df.head()
# Out:
#    شناسه کالا           دسته‌بندی          رنگ  متریال     سبک طراحی  \
# 0           1     زیبایی و بهداشت   روشن و شاد   پارچه          مدرن
# 1           2  ورزش و تناسب اندام  تیره و لوکس  ترکیبی  فانتزی و خاص
# 2           3     زیبایی و بهداشت         خنثی   فلزات  فانتزی و خاص
# 3           4   پازل‌ها و بازی‌ها         اصلی    چوبی          هنری
# 4           5   پازل‌ها و بازی‌ها         اصلی    چوبی          هنری
#
#      کاربرد  جنسیت
# 0  تکنولوژی  زنانه
# 1     سلامت   خنثی
# 2      کاری   خنثی
# 3      دکور   خنثی
# 4    سرگرمی  زنانه

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ## Items Dataset

# %%
items_df.shape
# Out:
# (1400, 7)

# %%
items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   شناسه کالا  1400 non-null   int64
#  1   دسته‌بندی   1400 non-null   object
#  2   رنگ         1400 non-null   object
#  3   متریال      1400 non-null   object
#  4   سبک طراحی   1400 non-null   object
#  5   کاربرد      1400 non-null   object
#  6   جنسیت       1400 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 76.7+ KB

# %%
# Category count histogram
sns.countplot(data = items_df, x = 'دسته‌بندی')
# Out:
# <Axes: xlabel='دسته\u200cبندی', ylabel='count'>

# %%
# Items colors count histogram
sns.countplot(data = items_df, x = 'رنگ')
# Out:
# <Axes: xlabel='رنگ', ylabel='count'>

# %%
# Items Material count histogrma
sns.countplot(data = items_df, x = 'متریال')
# Out:
# <Axes: xlabel='متریال', ylabel='count'>

# %%
# Items Designs count histogram
sns.countplot(data = items_df, x= 'سبک طراحی')
# Out:
# <Axes: xlabel='سبک طراحی', ylabel='count'>

# %%
# Items Use count histogram
sns.countplot(data = items_df, x = 'کاربرد')
# Out:
# <Axes: xlabel='کاربرد', ylabel='count'>

# %%
#Items sex count histogram
sns.countplot(data = items_df, x = 'جنسیت')
# Out:
# <Axes: xlabel='جنسیت', ylabel='count'>

# %% [markdown]
# ## Users Dataset

# %%
users_df.shape
# Out:
# (500, 11)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   شناسه کاربر                    500 non-null    int64
#  1   سن                             500 non-null    int64
#  2   جنسیت                          500 non-null    object
#  3   اولویت دسته‌بندی 1             500 non-null    object
#  4   اولویت دسته‌بندی 2             500 non-null    object
#  5   اولویت دسته‌بندی 3             500 non-null    object
#  6   ویژگی روان‌شناختی              500 non-null    object
#  7   علاقه به متریال                500 non-null    object
#  8   سبک کاری مورد علاقه            500 non-null    object
#  9   مناسبت هدیه                    500 non-null    object
#  10  نوع ارتباط با فرد گیرنده هدیه  500 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 43.1+ KB

# %%
# Users Age Histogram
sns.histplot(data = users_df, x= 'سن')
# Out:
# <Axes: xlabel='سن', ylabel='Count'>

# %%
#Users Gender count Histogram
sns.countplot(data = users_df, x = 'جنسیت')
# Out:
# <Axes: xlabel='جنسیت', ylabel='count'>

# %%
# Users First Priority Category Count Histogram
sns.countplot(data=users_df, x="اولویت دسته‌بندی 1")
# Out:
# <Axes: xlabel='اولویت دسته\u200cبندی 1', ylabel='count'>

# %%
# Users second priorty Categories Count Histogram
sns.countplot(data=users_df, x="اولویت دسته‌بندی 2")
# Out:
# <Axes: xlabel='اولویت دسته\u200cبندی 2', ylabel='count'>

# %%
# Users third priorty Categories Count Histogram
sns.countplot(data=users_df, x="اولویت دسته‌بندی 3")
# Out:
# <Axes: xlabel='اولویت دسته\u200cبندی 3', ylabel='count'>

# %%
# Users Mental Count Histogram
sns.countplot(data=users_df, x="ویژگی روان‌شناختی")
# Out:
# <Axes: xlabel='ویژگی روان\u200cشناختی', ylabel='count'>

# %%
# Material Favoriteness Count Histogram
sns.countplot(data=users_df, x="علاقه به متریال")
# Out:
# <Axes: xlabel='علاقه به متریال', ylabel='count'>

# %%
# Users Favorite Designs Count Histogram
sns.countplot(data=users_df, x="سبک کاری مورد علاقه")
# Out:
# <Axes: xlabel='سبک کاری مورد علاقه', ylabel='count'>

# %%
# Users Favorite Design Count Histogram
sns.countplot(data=users_df, x="سبک کاری مورد علاقه")
# Out:
# <Axes: xlabel='سبک کاری مورد علاقه', ylabel='count'>

# %%
# Users Events count histogram
sns.countplot(data=users_df, x="مناسبت هدیه")
# Out:
# <Axes: xlabel='مناسبت هدیه', ylabel='count'>

# %%
# Users Relationship count histogram
sns.countplot(data=users_df, x="نوع ارتباط با فرد گیرنده هدیه")
# Out:
# <Axes: xlabel='نوع ارتباط با فرد گیرنده هدیه', ylabel='count'>
